# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/ADITYA/Desktop/TCS/Power-Networks-LCL.csv")

# %%
data[data.LCLid == 'MAC000018'].head(10)
# Out:
#             LCLid stdorToU                     DateTime    KWh    Acorn  \
# 326612  MAC000018      Std  2011-12-07 09:30:00.0000000  0.303  ACORN-E
# 326613  MAC000018      Std  2011-12-07 10:00:00.0000000  0.200  ACORN-E
# 326614  MAC000018      Std  2011-12-07 10:30:00.0000000  0.218  ACORN-E
# 326615  MAC000018      Std  2011-12-07 11:00:00.0000000  0.209  ACORN-E
# 326616  MAC000018      Std  2011-12-07 11:30:00.0000000  0.210  ACORN-E
# 326617  MAC000018      Std  2011-12-07 12:00:00.0000000  0.238  ACORN-E
# 326618  MAC000018      Std  2011-12-07 12:30:00.0000000  0.439  ACORN-E
# 326619  MAC000018      Std  2011-12-07 13:00:00.0000000  0.983  ACORN-E
# 326620  MAC000018      Std  2011-12-07 13:30:00.0000000  0.352  ACORN-E
# 326621  MAC000018      Std  2011-12-07 14:00:00.0000000  0.279  ACORN-E
#
#        Acorn_grouped
# 326612      Affluent
# 326613      Affluent
# 326614      Affluent
# 326615      Affluent
# 326616      Affluent
# 326617      Affluent
# 326618      Affluent
# 326619      Affluent
# 326620      Affluent
# 326621      Affluent

# %%
len(data['LCLid'].unique().tolist())
# Out:
# 30

# %%
ar = []
for i in data['LCLid']:
    if i not in ar:
        ar.append(i)

# %%
data[data.LCLid == "MAC000034"].shape[0]
# Out:
# 39069

# %%
arr = []
for i in ar:
    arr.append(data[data.LCLid == i].shape[0])

# %%
number = []
for i in arr:
    number.append(int(i))

# %%
import numpy as np
np.array(number)
# Out:
# array([24157, 35468, 31676, 36460, 25045, 26012, 25237, 25048, 23704,
#        24669, 29613, 19523, 39081, 39070, 39078, 39078, 39071, 39068,
#        39026, 39064, 39064, 39068, 32157, 39063, 39066, 39068, 39070,
#        39069, 39023, 16175])

# %%
import numpy as np
np.array(arr)
# Out:
# array([24157, 35468, 31676, 36460, 25045, 26012, 25237, 25048, 23704,
#        24669, 29613, 19523, 39081, 39070, 39078, 39078, 39071, 39068,
#        39026, 39064, 39064, 39068, 32157, 39063, 39066, 39068, 39070,
#        39069, 39023, 16175])

# %%
ids = []
num = [12,14,15]
for i in num:
    ids.append(ar[i])

# %%
ids
# Out:
# ['MAC000018', 'MAC000020', 'MAC000021']

# %%
for i in ids:
    print(data[data.LCLid == i].count())
# Out:
# LCLid            39081
# stdorToU         39081
# DateTime         39081
# KWh              39081
# Acorn            39081
# Acorn_grouped    39081
# dtype: int64
# LCLid            39078
# stdorToU         39078
# DateTime         39078
# KWh              39078
# Acorn            39078
# Acorn_grouped    39078
# dtype: int64
# LCLid            39078
# stdorToU         39078
# DateTime         39078
# KWh              39078
# Acorn            39078
# Acorn_grouped    39078
# dtype: int64

# %%
df = data['LCLid']

# %%
df = list(df)

# %%
df.index('MAC000018')
# Out:
# 326612

# %%
df.index('MAC000020')
# Out:
# 404763

# %%
df.index('MAC000021')
# Out:
# 443841

# %%
array = [1,2,3,4,5,6,7,8]

# %%
array[-2:]
# Out:
# [7, 8]

# %%
df_new = data.copy()

# %%
df1 = df_new[326612:326612+39081]

# %%
df2 = df_new[404763:404763+39078]

# %%
df3 = df_new[443841:443841+39078]

# %%
df3['Acorn'].unique()
# Out:
# array(['ACORN-E'], dtype=object)

# %%
df3['Acorn_grouped'].unique()
# Out:
# array(['Affluent'], dtype=object)

# %%
df2['Acorn'].unique()
# Out:
# array(['ACORN-J'], dtype=object)

# %%
df2['Acorn_grouped'].unique()
# Out:
# array(['Comfortable'], dtype=object)

# %%
df1['Acorn'].unique()
# Out:
# array(['ACORN-E'], dtype=object)

# %%
df1['Acorn_grouped'].unique()
# Out:
# array(['Affluent'], dtype=object)

# %%
df1.head()
# Out:
#             LCLid stdorToU                     DateTime    KWh    Acorn  \
# 326612  MAC000018      Std  2011-12-07 09:30:00.0000000  0.303  ACORN-E
# 326613  MAC000018      Std  2011-12-07 10:00:00.0000000  0.200  ACORN-E
# 326614  MAC000018      Std  2011-12-07 10:30:00.0000000  0.218  ACORN-E
# 326615  MAC000018      Std  2011-12-07 11:00:00.0000000  0.209  ACORN-E
# 326616  MAC000018      Std  2011-12-07 11:30:00.0000000  0.210  ACORN-E
#
#        Acorn_grouped
# 326612      Affluent
# 326613      Affluent
# 326614      Affluent
# 326615      Affluent
# 326616      Affluent

# %%
df1['DateTime'][-5:]
# Out:
# 365688    2014-02-27 22:30:00.0000000
# 365689    2014-02-27 23:00:00.0000000
# 365690    2014-02-27 23:30:00.0000000
# 365691    2014-02-28 00:00:00.0000000
# 365692    2014-02-28 00:00:00.0000000
# Name: DateTime, dtype: object

# %%
from datetime import datetime

# %%
df1["DateTime"] = df1["DateTime"].apply(pd.to_datetime)
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2["DateTime"] = df2["DateTime"].apply(pd.to_datetime)
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3["DateTime"] = df3["DateTime"].apply(pd.to_datetime)
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['year'] = df1['DateTime'].dt.year 
df1['month'] = df1['DateTime'].dt.month 
df1['day'] = df1['DateTime'].dt.day 
df1['hour'] = df1['DateTime'].dt.hour 
df1['minute'] = df1['DateTime'].dt.minute
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df2['year'] = df2['DateTime'].dt.year 
df2['month'] = df2['DateTime'].dt.month 
df2['day'] = df2['DateTime'].dt.day 
df2['hour'] = df2['DateTime'].dt.hour 
df2['minute'] = df2['DateTime'].dt.minute
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df3['year'] = df3['DateTime'].dt.year 
df3['month'] = df3['DateTime'].dt.month 
df3['day'] = df3['DateTime'].dt.day 
df3['hour'] = df3['DateTime'].dt.hour 
df3['minute'] = df3['DateTime'].dt.minute
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
del df1["DateTime"]

# %%
del df2["DateTime"]

# %%
del df3["DateTime"]

# %%
df1.head(10)
# Out:
#             LCLid stdorToU    KWh    Acorn Acorn_grouped  year  month  day  \
# 326612  MAC000018      Std  0.303  ACORN-E      Affluent  2011     12    7
# 326613  MAC000018      Std  0.200  ACORN-E      Affluent  2011     12    7
# 326614  MAC000018      Std  0.218  ACORN-E      Affluent  2011     12    7
# 326615  MAC000018      Std  0.209  ACORN-E      Affluent  2011     12    7
# 326616  MAC000018      Std  0.210  ACORN-E      Affluent  2011     12    7
# 326617  MAC000018      Std  0.238  ACORN-E      Affluent  2011     12    7
# 326618  MAC000018      Std  0.439  ACORN-E      Affluent  2011     12    7
# 326619  MAC000018      Std  0.983  ACORN-E      Affluent  2011     12    7
# 326620  MAC000018      Std  0.352  ACORN-E      Affluent  2011     12    7
# 326621  MAC000018      Std  0.279  ACORN-E      Affluent  2011     12    7
#
#         hour  minute
# 326612     9      30
# 326613    10       0
# 326614    10      30
# 326615    11       0
# 326616    11      30
# 326617    12       0
# 326618    12      30
# 326619    13       0
# 326620    13      30
# 326621    14       0

# %%
df2.tail(10)
# Out:
#             LCLid stdorToU    KWh    Acorn Acorn_grouped  year  month  day  \
# 443831  MAC000020      Std  0.284  ACORN-J   Comfortable  2014      2   27
# 443832  MAC000020      Std  0.237  ACORN-J   Comfortable  2014      2   27
# 443833  MAC000020      Std  0.204  ACORN-J   Comfortable  2014      2   27
# 443834  MAC000020      Std  0.257  ACORN-J   Comfortable  2014      2   27
# 443835  MAC000020      Std  0.204  ACORN-J   Comfortable  2014      2   27
# 443836  MAC000020      Std  0.213  ACORN-J   Comfortable  2014      2   27
# 443837  MAC000020      Std  0.089  ACORN-J   Comfortable  2014      2   27
# 443838  MAC000020      Std  0.044  ACORN-J   Comfortable  2014      2   27
# 443839  MAC000020      Std  0.060  ACORN-J   Comfortable  2014      2   28
# 443840  MAC000020      Std  0.060  ACORN-J   Comfortable  2014      2   28
#
#         hour  minute
# 443831    20       0
# 443832    20      30
# 443833    21       0
# 443834    21      30
# 443835    22       0
# 443836    22      30
# 443837    23       0
# 443838    23      30
# 443839     0       0
# 443840     0       0

# %%
df3[df3.year == 2012].head(10)
# Out:
#             LCLid stdorToU    KWh    Acorn Acorn_grouped  year  month  day  \
# 445022  MAC000021      Std  0.480  ACORN-E      Affluent  2012      1    1
# 445023  MAC000021      Std  0.444  ACORN-E      Affluent  2012      1    1
# 445024  MAC000021      Std  0.530  ACORN-E      Affluent  2012      1    1
# 445025  MAC000021      Std  0.484  ACORN-E      Affluent  2012      1    1
# 445026  MAC000021      Std  0.548  ACORN-E      Affluent  2012      1    1
# 445027  MAC000021      Std  0.438  ACORN-E      Affluent  2012      1    1
# 445028  MAC000021      Std  0.398  ACORN-E      Affluent  2012      1    1
# 445029  MAC000021      Std  0.325  ACORN-E      Affluent  2012      1    1
# 445030  MAC000021      Std  0.395  ACORN-E      Affluent  2012      1    1
# 445031  MAC000021      Std  0.385  ACORN-E      Affluent  2012      1    1
#
#         hour  minute
# 445022     0       0
# 445023     0      30
# 445024     1       0
# 445025     1      30
# 445026     2       0
# 445027     2      30
# 445028     3       0
# 445029     3      30
# 445030     4       0
# 445031     4      30

# %%
df1.head()
# Out:
#             LCLid stdorToU    KWh    Acorn Acorn_grouped  year  month  day  \
# 326612  MAC000018      Std  0.303  ACORN-E      Affluent  2011     12    7
# 326613  MAC000018      Std  0.200  ACORN-E      Affluent  2011     12    7
# 326614  MAC000018      Std  0.218  ACORN-E      Affluent  2011     12    7
# 326615  MAC000018      Std  0.209  ACORN-E      Affluent  2011     12    7
# 326616  MAC000018      Std  0.210  ACORN-E      Affluent  2011     12    7
#
#         hour  minute
# 326612     9      30
# 326613    10       0
# 326614    10      30
# 326615    11       0
# 326616    11      30

# %% [markdown]
# - To convert string into integer

# %%
#pd.factorize(df4.LCLid)[0]

# %%
df4 = df1.copy()

# %%
del df4['LCLid']
del df4['Acorn_grouped']
del df4['Acorn']
del df4['stdorToU']

# %%
import matplotlib.pyplot as plt

# %%
df4.corr(method='pearson').style.format("{:.3}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col2 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col3 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col4 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col5 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col3 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col4 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col0 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col3 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col4 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col5 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row3_col0 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row3_col2 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row3_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row3_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row4_col0 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row5_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row5_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row5_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row5_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row5_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_81906ca6_c898_11e9_8922_a86bad52ae46row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_81906ca6_c898_11e9_8922_a86bad52ae46" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >KWh</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >month</th>        <th class="col_heading level0 col3" >day</th>        <th class="col_heading level0 col4" >hour</th>        <th class="col_heading level0 col5" >minute</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_81906ca6_c898_11e9_8922_a86bad52ae46level0_row0" class="row_heading level0 row0" >KWh</th>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col1" class="data row0 col1" >-0.136</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col2" class="data row0 col2" >-0.0126</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col3" class="data row0 col3" >-0.00766</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col4" class="data row0 col4" >0.192</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row0_col5" class="data row0 col5" >-0.00528</td>
#             </tr>
#             <tr>
#                         <th id="T_81906ca6_c898_11e9_8922_a86bad52ae46level0_row1" class="row_heading level0 row1" >year</th>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col0" class="data row1 col0" >-0.136</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col2" class="data row1 col2" >-0.316</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col3" class="data row1 col3" >-0.0405</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col4" class="data row1 col4" >-0.00126</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row1_col5" class="data row1 col5" >-0.000109</td>
#             </tr>
#             <tr>
#                         <th id="T_81906ca6_c898_11e9_8922_a86bad52ae46level0_row2" class="row_heading level0 row2" >month</th>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col0" class="data row2 col0" >-0.0126</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col1" class="data row2 col1" >-0.316</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col3" class="data row2 col3" >0.0324</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col4" class="data row2 col4" >0.000835</td>
#                         <td id="T_81906ca6_c898_11e9_8922_a86bad52ae46row2_col5" class="data row2 col5" >6.84e-05</td>
#             </tr>
#             <tr>
#                         <th id="T_81906ca6_c898_11e9_8922_a86bad52ae46level0_row3" class="row_heading leve

# %%
df4['KWh'] = df4.KWh

# %%
#sj_correlations = sj_df.corr()
df4_correlations = df4.corr()

# %%
import seaborn as sns

# %%
#correation heat map to check correlation between two attributes so we can eliminate one if required(for san juan)
plt.rcParams['figure.figsize'] = [10, 6]
df4_corr_heat = sns.heatmap(df4_correlations)
plt.title('MAC000018 Correlations')
# Out:
# Text(0.5,1,'MAC000018 Correlations')

# %%
df4.head()
# Out:
#           KWh  year  month  day  hour  minute
# 326612  0.303  2011     12    7     9      30
# 326613  0.200  2011     12    7    10       0
# 326614  0.218  2011     12    7    10      30
# 326615  0.209  2011     12    7    11       0
# 326616  0.210  2011     12    7    11      30

# %%
# correlation graph to check which class is responsible for more number of dengue(for san juan)
plt.rcParams['figure.figsize'] = [10, 6]
(df4_correlations
     .KWh
     .drop('KWh') 
     .sort_values(ascending=False)
     .plot
     .barh())

# %%
df4.head(6)
# Out:
#           KWh  year  month  day  hour  minute
# 326612  0.303  2011     12    7     9      30
# 326613  0.200  2011     12    7    10       0
# 326614  0.218  2011     12    7    10      30
# 326615  0.209  2011     12    7    11       0
# 326616  0.210  2011     12    7    11      30
# 326617  0.238  2011     12    7    12       0

# %%
df4.tail(6)
# Out:
#           KWh  year  month  day  hour  minute
# 365687  0.376  2014      2   27    22       0
# 365688  0.379  2014      2   27    22      30
# 365689  0.382  2014      2   27    23       0
# 365690  0.383  2014      2   27    23      30
# 365691  0.380  2014      2   28     0       0
# 365692  0.380  2014      2   28     0       0

# %%
d = list(df4.hour)
d1 = list(df2.hour)
d2 = list(df3.hour)

# %%
l = {}
l1 = {}
l2 = {}

# %%
n = 0
for i in range(23):
    n = d.count(i)
    l[i] = n
print(l)
# Out:
# {0: 1654, 1: 1626, 2: 1626, 3: 1626, 4: 1626, 5: 1626, 6: 1626, 7: 1626, 8: 1626, 9: 1627, 10: 1628, 11: 1628, 12: 1628, 13: 1628, 14: 1628, 15: 1628, 16: 1628, 17: 1628, 18: 1628, 19: 1628, 20: 1628, 21: 1628, 22: 1628}

# %%
n = 0
for i in range(23):
    n = d1.count(i)
    l1[i] = n
print(l1)
# Out:
# {0: 1654, 1: 1626, 2: 1626, 3: 1626, 4: 1626, 5: 1626, 6: 1626, 7: 1626, 8: 1626, 9: 1627, 10: 1628, 11: 1628, 12: 1628, 13: 1628, 14: 1628, 15: 1628, 16: 1628, 17: 1627, 18: 1628, 19: 1628, 20: 1627, 21: 1628, 22: 1628}

# %%
n = 0
for i in range(23):
    n = d2.count(i)
    l2[i] = n
print(l2)
# Out:
# {0: 1654, 1: 1626, 2: 1626, 3: 1626, 4: 1626, 5: 1625, 6: 1626, 7: 1626, 8: 1626, 9: 1626, 10: 1628, 11: 1627, 12: 1628, 13: 1628, 14: 1628, 15: 1628, 16: 1628, 17: 1628, 18: 1628, 19: 1628, 20: 1628, 21: 1628, 22: 1628}

# %%
df4.isna().sum()
# Out:
# KWh       0
# year      0
# month     0
# day       0
# hour      0
# minute    0
# dtype: int64

# %%
df4 = df4.drop(df4.index[0])

# %%
d = df4.copy()

# %%
d.year = d.year.astype(int)

# %%
d.month = d.month.astype(int)

# %%
d.hour = d.hour.astype(int)

# %%
d.minute = d.minute.astype(int)

# %%
len(d)
# Out:
# 39080

# %%
d.dtypes
# Out:
# KWh       float64
# year        int32
# month       int32
# day         int64
# hour        int32
# minute      int32
# dtype: object

# %%
del d['KWh']

# %%
d.loc[d['minute'] == 30] = 0

# %%
d.loc[d['minute'] == 30].count()
# Out:
# year      0
# month     0
# day       0
# hour      0
# minute    0
# dtype: int64

# %%
d = d.astype(int)

# %%
d = d.join(df4.KWh)

# %%
def years(y):
    y = y % 2000
    return y

# %%
d['year'] = years(d['year'])

# %%
d.head()
# Out:
#         year  month  day  hour  minute    KWh
# 326613    11     12    7    10       0  0.200
# 326614     0      0    0     0       0  0.218
# 326615    11     12    7    11       0  0.209
# 326616     0      0    0     0       0  0.210
# 326617    11     12    7    12       0  0.238

# %%
ar = df4['minute']

# %%
ar = list(ar)

# %%
array = []
a = 0
for i in range(len(ar)-1):
    if a < len(ar)-1:
        if ar[a] == ar[a+1]:
            array.append(a)
    a = a + 2
print(array)
# Out:
# [364, 3342, 6320, 9298, 12276, 15254, 18232, 21210, 24188, 27166, 30144, 33122, 36100, 39078]

# %%
len(array)
# Out:
# 14

# %%
a = 0
for i in array:
    d = d.drop(d.index[[i-a,i+1-a]])
    a = a + 2

# %%
#def wtokw(w):
   # w = w*1000
   # return w

# %%
#d['KWh'] = wtokw(d['KWh'])

# %%
arr = d.KWh

# %%
arr = list(arr)

# %%
a = 0
for i in range(len(arr)):
    if a < len(arr)-1:
        arr[a] = arr[a] + arr[a+1]
        a = a + 2
print(arr[0:60])
# Out:
# [0.41800000000000004, 0.218, 0.419, 0.21, 0.677, 0.439, 1.335, 0.35200000000000004, 0.6339999999999999, 0.355, 0.475, 0.196, 0.496, 0.319, 0.86, 0.39799999999999996, 0.6499999999999999, 0.371, 0.759, 0.315, 0.6759999999999999, 0.344, 0.649, 0.256, 0.771, 0.434, 0.9180000000000001, 0.36200000000000004, 0.428, 0.134, 0.244, 0.125, 0.25, 0.12300000000000001, 0.242, 0.121, 0.242, 0.121, 0.241, 0.12, 0.245, 0.122, 0.311, 0.158, 0.558, 0.318, 0.599, 0.27399999999999997, 0.837, 0.40700000000000003, 0.9830000000000001, 0.48200000000000004, 0.933, 0.46, 1.591, 1.071, 1.168, 0.425, 0.91, 0.47700000000000004]

# %%
for i in range(len(arr)):
    if i % 2 != 0:
        arr[i] = 0
print(arr[0:60])
# Out:
# [0.41800000000000004, 0, 0.419, 0, 0.677, 0, 1.335, 0, 0.6339999999999999, 0, 0.475, 0, 0.496, 0, 0.86, 0, 0.6499999999999999, 0, 0.759, 0, 0.6759999999999999, 0, 0.649, 0, 0.771, 0, 0.9180000000000001, 0, 0.428, 0, 0.244, 0, 0.25, 0, 0.242, 0, 0.242, 0, 0.241, 0, 0.245, 0, 0.311, 0, 0.558, 0, 0.599, 0, 0.837, 0, 0.9830000000000001, 0, 0.933, 0, 1.591, 0, 1.168, 0, 0.91, 0]

# %%
for i in range(len(arr)):
    if i < len(arr):
        if arr[i] == 0:
            arr.pop(i)
len(arr)
# Out:
# 19526

# %%
d.drop(d[d['year'] < 1].index, inplace = True)

# %%
del d['KWh']

# %%
d['KWh'] = arr

# %%
del d['minute']

# %%
d.head()
# Out:
#         year  month  day  hour    KWh
# 326613    11     12    7    10  0.418
# 326615    11     12    7    11  0.419
# 326617    11     12    7    12  0.677
# 326619    11     12    7    13  1.335
# 326621    11     12    7    14  0.634

# %%
#train = d[0:int(len(d)*0.7)]
#test = d[int(len(d)*0.7):]

# %%
y = d['KWh'].values
x = d.drop(['KWh'],axis=1).values

# %%
from sklearn.linear_model import LinearRegression
from sklearn import model_selection, tree, linear_model
from sklearn.model_selection import train_test_split

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
linearRegressor = LinearRegression()

# %%
linearRegressor.fit(xTrain, yTrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
yPrediction = linearRegressor.predict(xTest)

# %%
import sklearn.metrics as metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, yPrediction))  
print('Mean Squared Error:', metrics.mean_squared_error(yTest, yPrediction))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, yPrediction)))
# Out:
# Mean Absolute Error: 0.2077735478727534
# Mean Squared Error: 0.10502197216183812
# Root Mean Squared Error: 0.32407093692868866

# %%
plt.scatter(yTest, yPrediction)
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0,0.5,'Predictions')

# %%
plt.plot(yTest)
plt.plot(yPrediction,color='red')

# %%
import xgboost
xgb = xgboost.XGBRegressor(n_estimators=3000, learning_rate=0.01, gamma=0, subsample=0.60,
                           colsample_bytree=1, max_depth=20)

# %%
xgb.fit(xTrain, yTrain)
# Out:
# [12:36:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.01, max_delta_step=0,
#        max_depth=20, min_child_weight=1, missing=None, n_estimators=3000,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=0.6, verbosity=1)

# %%
Prediction = xgb.predict(xTest)

# %%
import sklearn.metrics as metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, Prediction))  
print('Mean Squared Error:', metrics.mean_squared_error(yTest, Prediction))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, Prediction)))
# Out:
# Mean Absolute Error: 0.13700194817264866
# Mean Squared Error: 0.06217814496122859
# Root Mean Squared Error: 0.24935545905640122

# %%
plt.plot(yTest)
plt.plot(Prediction,color='red')

# %%
plt.scatter(yTest, Prediction)
plt.xlabel("True Values")
plt.ylabel("Predictions")
# Out:
# Text(0,0.5,'Predictions')
